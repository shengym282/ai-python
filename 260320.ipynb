# %%
a=7
b=11
c=a
a=b
b=c

# %%
print(a)
# Out:
# 11

# %%
print(b)
# Out:
# 7

# %%
print(c)
# Out:
# 7

# %%
a=7
b=11

# %%
a,b=b,a

# %%
print(a)
print(b)
# Out:
# 11
# 7

# %%
age=int(input("나이를 입력하시오"))
name=input("이름을 입력하시오")
# Out:
# 나이를 입력하시오20
# 이름을 입력하시오홀길동

# %%
b=input()
# Out:
# 30

# %%
a
# Out:
# 11

# %%
b
# Out:
# '30'

# %%
int(a)-int(b)
# Out:
# -19

# %%
c
# Out:
# 7

# %%
print(10,20,30)
# Out:
# 10 20 30

# %%
print("a=",a,"b=",b,"c=",c)
# Out:
# a= 11 b= 30 c= 7

# %%
print(f'이름은{name}이고 나이는{age}입니다')
# Out:
# 이름은홀길동이고 나이는20입니다

# %%
minute1=int(input("분을 입력하세요"))
# Out:
# 분을 입력하세요150

# %%
hour = minute1//60
minute2 = minute1%60

print(f'{minute1}분은 {hour}시간 {minute2}분입니다')
# Out:
# 150분은 2시간 30분입니다

# %%
n = int(input("숫자를 입력하세요: "))
if n % 2 == 0:
    print("짝수입니다.")
else:
    print("홀수입니다.")
# Out:
# 숫자를 입력하세요: 10
# 짝수입니다.

# %%
print("음료 가격")
print("커피 2000원")
print("라떼 3000원")
print("녹차 2500원")
print("주스 2800원")
# Out:
# 음료 가격
# 커피 2000원
# 라떼 3000원
# 녹차 2500원
# 주스 2800원

# %%
aaa=int(input("커피 주문수"))
bbb=int(input("라떼 주문수"))
ccc=int(input("녹차 주문수"))
ddd=int(input("주스 주문수"))
money=aaa*2000+bbb*3000+ccc*2500+ddd*2800
print(f'주문금액:{money}원')
# Out:
# 커피 주문수1
# 라떼 주문수1
# 녹차 주문수1
# 주스 주문수1
# 주문금액:10300원
