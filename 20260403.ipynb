# %%
import random
answer=random.randint(1,100)

# %%
answer
# Out:
# 60

# %%
user=int(input("추측값을 입력하시오"))
# Out:
# 추측값을 입력하시오50

# %%
count=0
while user!= answer:
  if user<answer:
    print("더 큰 수를 입력하시오")
    count+=1
  else:
    print("더 작은 수를 입력하시오")
    count+=1
  user=int(input("추측값을 입력하시오"))
print("총 시도 횟수:",count)
# Out:
# 더 큰 수를 입력하시오
# 추측값을 입력하시오55
# 더 큰 수를 입력하시오
# 추측값을 입력하시오60
# 총 시도 횟수: 2

# %%
num=int(input("숫자를 입력하세요"))

for i in range(1,num+1):
  if num % i ==0:
    print(i)
# Out:
# 숫자를 입력하세요90
# 1
# 2
# 3
# 5
# 6
# 9
# 10
# 15
# 18
# 30
# 45
# 90
